# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('cereal.csv')
df.head()
# Out:
#                         Name mfr   calories    protein       fat     sodium  \
# 0                  100% Bran   N  212.12121  12.121212  3.030303  393.93939
# 1                   All-Bran   K  212.12121  12.121212  3.030303  787.87879
# 2  All-Bran with Extra Fiber   K  100.00000   8.000000  0.000000  280.00000
# 3    Apple Cinnamon Cheerios   G  146.66667   2.666667  2.666667  240.00000
# 4                Apple Jacks   K  110.00000   2.000000  0.000000  125.00000
#
#        fibre     carbo     sugars  shelf  potassium  vitamins
# 0  30.303030  15.15152  18.181818      3  848.48485  enriched
# 1  27.272727  21.21212  15.151515      3  969.69697  enriched
# 2  28.000000  16.00000   0.000000      3  660.00000  enriched
# 3   2.000000  14.00000  13.333333      1   93.33333  enriched
# 4   1.000000  11.00000  14.000000      2   30.00000  enriched

# %%
df.columns
# Out:
# Index(['Name', 'mfr', 'calories', 'protein', 'fat', 'sodium', 'fibre', 'carbo',
#        'sugars', 'shelf', 'potassium', 'vitamins'],
#       dtype='object')

# %%
df_c = df[['Name',  'calories', 'protein', 'fat', 'sodium', 'fibre', 'carbo',
       'sugars',  'potassium', ]]
df_c.head()
# Out:
#                         Name   calories    protein       fat     sodium  \
# 0                  100% Bran  212.12121  12.121212  3.030303  393.93939
# 1                   All-Bran  212.12121  12.121212  3.030303  787.87879
# 2  All-Bran with Extra Fiber  100.00000   8.000000  0.000000  280.00000
# 3    Apple Cinnamon Cheerios  146.66667   2.666667  2.666667  240.00000
# 4                Apple Jacks  110.00000   2.000000  0.000000  125.00000
#
#        fibre     carbo     sugars  potassium
# 0  30.303030  15.15152  18.181818  848.48485
# 1  27.272727  21.21212  15.151515  969.69697
# 2  28.000000  16.00000   0.000000  660.00000
# 3   2.000000  14.00000  13.333333   93.33333
# 4   1.000000  11.00000  14.000000   30.00000

# %%
sns.distplot(df_c['calories'])
# Out:
# /home/icfoss/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_c['protein'])
# Out:
# /home/icfoss/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_c['fat'])
# Out:
# /home/icfoss/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_test = df[df['vitamins']=="enriched"]
df_test
# Out:
#                                      Name mfr   calories    protein       fat  \
# 0                               100% Bran   N  212.12121  12.121212  3.030303
# 1                                All-Bran   K  212.12121  12.121212  3.030303
# 2               All-Bran with Extra Fiber   K  100.00000   8.000000  0.000000
# 3                 Apple Cinnamon Cheerios   G  146.66667   2.666667  2.666667
# 4                             Apple Jacks   K  110.00000   2.000000  0.000000
# 5                                 Basic 4   G  173.33333   4.000000  2.666667
# 6                               Bran Chex   R  134.32836   2.985075  1.492537
# 7                             Bran Flakes   P  134.32836   4.477612  0.000000
# 8                            Cap'n'Crunch   Q  160.00000   1.333333  2.666667
# 9                                Cheerios   G   88.00000   4.800000  1.600000
# 10                  Cinnamon Toast Crunch   G  160.00000   1.333333  4.000000
# ...

# %%
#relation between different factors where vitamins equals to enriched

sns.pairplot(df_test)

# %%
df_test_n = df[df['vitamins']=="none"]
df_test_n
# Out:
#                          Name mfr   calories   protein  fat  sodium     fibre  \
# 46                Puffed Rice   Q   50.00000  1.000000  0.0     0.0  0.000000
# 53     Shredded Wheat 'n'Bran   N  134.32836  4.477612  0.0     0.0  5.970149
# 54  Shredded Wheat spoon size   N  134.32836  4.477612  0.0     0.0  4.477612
#
#        carbo  sugars  shelf  potassium vitamins
# 46  13.00000     0.0      3   15.00000     none
# 53  28.35821     0.0      1  208.95522     none
# 54  29.85075     0.0      1  179.10448     none

# %%
sns.pairplot(df_test_n)

# %%
df_test_h = df[df['vitamins']=="100%"]
df_test_h
# Out:
#                       Name mfr   calories  protein       fat     sodium  \
# 35  Just Right Fruit & Nut   K  186.66667      4.0  1.333333  226.66667
# 45              Product 19   K  100.00000      3.0  0.000000  320.00000
# 57       Total Corn Flakes   G  110.00000      2.0  1.000000  200.00000
# 58       Total Raisin Bran   G  140.00000      3.0  1.000000  190.00000
# 59       Total Whole Grain   G  100.00000      3.0  1.000000  200.00000
#
#        fibre     carbo  sugars  shelf  potassium vitamins
# 35  2.666667  26.66667    12.0      3  126.66667     100%
# 45  1.000000  20.00000     3.0      3   45.00000     100%
# 57  0.000000  21.00000     3.0      3   35.00000     100%
# 58  4.000000  15.00000    14.0      3  230.00000     100%
# 59  3.000000  16.00000     3.0      3  110.00000     100%

# %%
sns.pairplot(df_test_h)

# %%
df_test.columns
# Out:
# Index(['Name', 'mfr', 'calories', 'protein', 'fat', 'sodium', 'fibre', 'carbo',
#        'sugars', 'shelf', 'potassium', 'vitamins'],
#       dtype='object')

# %%
df_test1 = df_test[['Name', 'calories', 'protein', 'fat', 'sodium', 'fibre', 'carbo',
       'sugars', 'potassium']]

# %%
df_test1
# Out:
#                                      Name   calories    protein       fat  \
# 0                               100% Bran  212.12121  12.121212  3.030303
# 1                                All-Bran  212.12121  12.121212  3.030303
# 2               All-Bran with Extra Fiber  100.00000   8.000000  0.000000
# 3                 Apple Cinnamon Cheerios  146.66667   2.666667  2.666667
# 4                             Apple Jacks  110.00000   2.000000  0.000000
# 5                                 Basic 4  173.33333   4.000000  2.666667
# 6                               Bran Chex  134.32836   2.985075  1.492537
# 7                             Bran Flakes  134.32836   4.477612  0.000000
# 8                            Cap'n'Crunch  160.00000   1.333333  2.666667
# 9                                Cheerios   88.00000   4.800000  1.600000
# 10                  Cinnamon Toast Crunch  160.00000   1.333333  4.000000
# 11                               Clusters  220.00000   6.000000  4.000000
# ...

# %%
df_test.shape
# Out:
# (57, 12)

# %%
df['protein'].min()
# Out:
# 0.7518796999999999

# %%
df['calories'].min()
# Out:
# 50.0

# %%
df_p= df['calories'].argmin()
df.iloc[df_p]
# Out:
# Name         Puffed Rice
# mfr                    Q
# calories              50
# protein                1
# fat                    0
# sodium                 0
# fibre                  0
# carbo                 13
# sugars                 0
# shelf                  3
# potassium             15
# vitamins            none
# Name: 46, dtype: object

# %%
df_p= df['calories'].argmin()
df.iloc[df_p][0:1]
# Out:
# Name    Puffed Rice
# Name: 46, dtype: object

# %%
new_df =df[(df['calories']>400) | (df['protein']>10)]
new_df
# Out:
#           Name mfr   calories    protein       fat     sodium      fibre  \
# 0    100% Bran   N  212.12121  12.121212  3.030303  393.93939  30.303030
# 1     All-Bran   K  212.12121  12.121212  3.030303  787.87879  27.272727
# 30  Grape-Nuts   P  440.00000  12.000000  0.000000  680.00000  12.000000
#
#        carbo     sugars  shelf  potassium  vitamins
# 0   15.15152  18.181818      3  848.48485  enriched
# 1   21.21212  15.151515      3  969.69697  enriched
# 30  68.00000  12.000000      3  360.00000  enriched

# %%
df['fat'].min()
# Out:
# 0.0

# %%
d_x = df['fat'].argmin()
df.iloc[d_x]
# Out:
# Name         All-Bran with Extra Fiber
# mfr                                  K
# calories                           100
# protein                              8
# fat                                  0
# sodium                             280
# fibre                               28
# carbo                               16
# sugars                               0
# shelf                                3
# potassium                          660
# vitamins                      enriched
# Name: 2, dtype: object

# %%
d_x = df['fat'].argmin()
df.iloc[d_x][0:1]
# Out:
# Name    All-Bran with Extra Fiber
# Name: 2, dtype: object

# %%
n_df =df[(df['calories']>100) | (df['protein']>7)|(df['fat']>5) ]
n_df
# Out:
#                                      Name mfr   calories    protein       fat  \
# 0                               100% Bran   N  212.12121  12.121212  3.030303
# 1                                All-Bran   K  212.12121  12.121212  3.030303
# 2               All-Bran with Extra Fiber   K  100.00000   8.000000  0.000000
# 3                 Apple Cinnamon Cheerios   G  146.66667   2.666667  2.666667
# 4                             Apple Jacks   K  110.00000   2.000000  0.000000
# 5                                 Basic 4   G  173.33333   4.000000  2.666667
# 6                               Bran Chex   R  134.32836   2.985075  1.492537
# 7                             Bran Flakes   P  134.32836   4.477612  0.000000
# 8                            Cap'n'Crunch   Q  160.00000   1.333333  2.666667
# 10                  Cinnamon Toast Crunch   G  160.00000   1.333333  4.000000
# 11                               Clusters   G  220.00000   6.000000  4.000000
# ...

# %%
n_df =df[(df['calories']>100) | (df['protein']>7)&(df['fat']>3) ]
n_df
# Out:
#                                      Name mfr   calories    protein       fat  \
# 0                               100% Bran   N  212.12121  12.121212  3.030303
# 1                                All-Bran   K  212.12121  12.121212  3.030303
# 3                 Apple Cinnamon Cheerios   G  146.66667   2.666667  2.666667
# 4                             Apple Jacks   K  110.00000   2.000000  0.000000
# 5                                 Basic 4   G  173.33333   4.000000  2.666667
# 6                               Bran Chex   R  134.32836   2.985075  1.492537
# 7                             Bran Flakes   P  134.32836   4.477612  0.000000
# 8                            Cap'n'Crunch   Q  160.00000   1.333333  2.666667
# 10                  Cinnamon Toast Crunch   G  160.00000   1.333333  4.000000
# 11                               Clusters   G  220.00000   6.000000  4.000000
# 12                            Cocoa Puffs   G  110.00000   1.000000  1.000000
# ...

# %%
d_y = df['sodium'].min()
d_y
# Out:
# 0.0

# %%
d_s = df['sodium'].argmin()
df.iloc[d_s]
# Out:
# Name         Frosted Mini-Wheats
# mfr                            K
# calories                     125
# protein                     3.75
# fat                            0
# sodium                         0
# fibre                       3.75
# carbo                       17.5
# sugars                      8.75
# shelf                          2
# potassium                    125
# vitamins                enriched
# Name: 23, dtype: object

# %%
d_s1 = df['sodium'].argmin()
df.iloc[d_s1][0:1]
# Out:
# Name    Frosted Mini-Wheats
# Name: 23, dtype: object

# %%
#Combining & and | operations
ns_df =df[(df['calories']>100) & (df['protein']>7) | (df['fat']>3) |(df['sodium']>500) ]
ns_df
# Out:
#                      Name mfr   calories    protein       fat     sodium  \
# 0               100% Bran   N  212.12121  12.121212  3.030303  393.93939
# 1                All-Bran   K  212.12121  12.121212  3.030303  787.87879
# 10  Cinnamon Toast Crunch   G  160.00000   1.333333  4.000000  280.00000
# 11               Clusters   G  220.00000   6.000000  4.000000  280.00000
# 17     Cracklin' Oat Bran   K  220.00000   6.000000  6.000000  280.00000
# 30             Grape-Nuts   P  440.00000  12.000000  0.000000  680.00000
# 31     Great Grains Pecan   P  363.63636   9.090909  9.090909  227.27273
# 43   Oatmeal Raisin Crisp   G  260.00000   6.000000  4.000000  340.00000
# 47     Quaker Oat Squares   Q  200.00000   8.000000  2.000000  270.00000
# 49        Raisin Nut Bran   G  200.00000   6.000000  4.000000  280.00000
#
#         fibre     carbo     sugars  shelf  potassium  vitamins
# 0   30.303030  15.15152  18.181818      3  848.48485  enriched
# ...

# %%
d_f = df['fibre'].min()
d_f
# Out:
# 0.0

# %%
d_s1 = df['fibre'].argmin()
df.iloc[d_s1][0:1]
# Out:
# Name    Cap'n'Crunch
# Name: 8, dtype: object

# %%
d_s = df['fibre'].argmin()
df.iloc[d_s]
# Out:
# Name         Cap'n'Crunch
# mfr                     Q
# calories              160
# protein           1.33333
# fat               2.66667
# sodium            293.333
# fibre                   0
# carbo                  16
# sugars                 16
# shelf                   2
# potassium         46.6667
# vitamins         enriched
# Name: 8, dtype: object

# %%
ns_d_f =df[(df['calories']>100) & (df['protein']>7)|(df['fat']>3)&(df['sodium']>500)|(df['fibre']>20) ]
ns_d_f
# Out:
#                          Name mfr   calories    protein       fat     sodium  \
# 0                   100% Bran   N  212.12121  12.121212  3.030303  393.93939
# 1                    All-Bran   K  212.12121  12.121212  3.030303  787.87879
# 2   All-Bran with Extra Fiber   K  100.00000   8.000000  0.000000  280.00000
# 30                 Grape-Nuts   P  440.00000  12.000000  0.000000  680.00000
# 31         Great Grains Pecan   P  363.63636   9.090909  9.090909  227.27273
# 47         Quaker Oat Squares   Q  200.00000   8.000000  2.000000  270.00000
#
#         fibre     carbo     sugars  shelf  potassium  vitamins
# 0   30.303030  15.15152  18.181818      3  848.48485  enriched
# 1   27.272727  21.21212  15.151515      3  969.69697  enriched
# 2   28.000000  16.00000   0.000000      3  660.00000  enriched
# 30  12.000000  68.00000  12.000000      3  360.00000  enriched
# 31   9.090909  39.39394  12.121212      3  303.03030  enriched
# ...

# %%
d_f = df['carbo'].min()
d_f
# Out:
# 10.52632

# %%
d_c = df['carbo'].argmin()
df.iloc[d_c][0:1]
# Out:
# Name    Honey-comb
# Name: 34, dtype: object

# %%
df[df['vitamins']=="none"]
# Out:
#                          Name mfr   calories   protein  fat  sodium     fibre  \
# 46                Puffed Rice   Q   50.00000  1.000000  0.0     0.0  0.000000
# 53     Shredded Wheat 'n'Bran   N  134.32836  4.477612  0.0     0.0  5.970149
# 54  Shredded Wheat spoon size   N  134.32836  4.477612  0.0     0.0  4.477612
#
#        carbo  sugars  shelf  potassium vitamins
# 46  13.00000     0.0      3   15.00000     none
# 53  28.35821     0.0      1  208.95522     none
# 54  29.85075     0.0      1  179.10448     none

# %%
df[df['vitamins']=="100%"]
# Out:
#                       Name mfr   calories  protein       fat     sodium  \
# 35  Just Right Fruit & Nut   K  186.66667      4.0  1.333333  226.66667
# 45              Product 19   K  100.00000      3.0  0.000000  320.00000
# 57       Total Corn Flakes   G  110.00000      2.0  1.000000  200.00000
# 58       Total Raisin Bran   G  140.00000      3.0  1.000000  190.00000
# 59       Total Whole Grain   G  100.00000      3.0  1.000000  200.00000
#
#        fibre     carbo  sugars  shelf  potassium vitamins
# 35  2.666667  26.66667    12.0      3  126.66667     100%
# 45  1.000000  20.00000     3.0      3   45.00000     100%
# 57  0.000000  21.00000     3.0      3   35.00000     100%
# 58  4.000000  15.00000    14.0      3  230.00000     100%
# 59  3.000000  16.00000     3.0      3  110.00000     100%

# %%
df[df['shelf']>2]
# Out:
#                                      Name mfr   calories    protein       fat  \
# 0                               100% Bran   N  212.12121  12.121212  3.030303
# 1                                All-Bran   K  212.12121  12.121212  3.030303
# 2               All-Bran with Extra Fiber   K  100.00000   8.000000  0.000000
# 5                                 Basic 4   G  173.33333   4.000000  2.666667
# 7                             Bran Flakes   P  134.32836   4.477612  0.000000
# 11                               Clusters   G  220.00000   6.000000  4.000000
# 17                     Cracklin' Oat Bran   K  220.00000   6.000000  6.000000
# 18                                Crispix   K  110.00000   2.000000  0.000000
# 19                 Crispy Wheat & Raisins   G  133.33333   2.666667  1.333333
# 20                            Double Chex   R  133.33333   2.666667  0.000000
# 24  Fruit & Fibre: Dates Walnuts and Oats   P  179.10448   4.477612  2.985075
# ...

# %%
df[df['mfr']=='K']
# Out:
#                          Name mfr   calories    protein       fat     sodium  \
# 1                    All-Bran   K  212.12121  12.121212  3.030303  787.87879
# 2   All-Bran with Extra Fiber   K  100.00000   8.000000  0.000000  280.00000
# 4                 Apple Jacks   K  110.00000   2.000000  0.000000  125.00000
# 14                Corn Flakes   K  100.00000   2.000000  0.000000  290.00000
# 15                  Corn Pops   K  110.00000   1.000000  0.000000   90.00000
# 17         Cracklin' Oat Bran   K  220.00000   6.000000  6.000000  280.00000
# 18                    Crispix   K  110.00000   2.000000  0.000000  220.00000
# 21                Froot Loops   K  110.00000   2.000000  1.000000  125.00000
# 22             Frosted Flakes   K  146.66667   1.333333  0.000000  266.66667
# 23        Frosted Mini-Wheats   K  125.00000   3.750000  0.000000    0.00000
# 25              Fruitful Bran   K  179.10448   4.477612  0.000000  358.20896
# ...

# %%
d_f_s = df['sugars'].min()
d_f_s
# Out:
# 0.0

# %%
d_f_s1 = df['sugars'].argmin()
df.iloc[d_f_s1][0:1]
# Out:
# Name    All-Bran with Extra Fiber
# Name: 2, dtype: object

# %%
d_f_s1 = df['sugars'].argmin()
df.iloc[d_f_s1]
# Out:
# Name         All-Bran with Extra Fiber
# mfr                                  K
# calories                           100
# protein                              8
# fat                                  0
# sodium                             280
# fibre                               28
# carbo                               16
# sugars                               0
# shelf                                3
# potassium                          660
# vitamins                      enriched
# Name: 2, dtype: object
